# %% [markdown]
# ___
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://d33wubrfki0l68.cloudfront.net/4ec62c1c925a380c912ddad740d18554c6822a11/fabe4/img/sponsors/iteso-university.png" width="300" height="500" />
#
#
# ### <font color='navy'> Simulación de procesos financieros.
#
# **Nombres:** Integrante 1: Daniel Pastrana. Integrante 2: Mario García.
#
# **Fecha:** 07 de noviembre del 2023.
#
# **Expediente** : 733982. 740322.
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# **Link Github**: https://github.com/DPastranaV/Proyecto_Modulo1
#
# # Proyecto TEMA-2

# %% [markdown]
# <img style="float: right; margin: 0px 0px 15px 15px;" src="https://upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Los_Angeles_Lakers_logo.svg/1280px-Los_Angeles_Lakers_logo.svg.png" width="300px" height="100px" />
#
#
# # Lakers Season Prediction
# > Para este proyecto, utilizaremos la simulación para predecir el éxito en la siguiente temporada del equipo de la NBA, Los Angeles Lakers. Este proyecto se centrará en predecir si el equipo alcanzará las finales. La simulación se realizará tomando en cuenta cuatro nodos o variables, obtenidos de las estadísticas del equipo desde la temporada 2000-01.

# %% [markdown]
# ## Objetivos.
#
# ### Objetivo general
#
# > - Predecir si los Lakers llegarán a los playoffs y serán campeones este año.
#
# #### Objetivos específicos
#
# > - Simular los puntos por partido que anotarán los Lakers.
# > - Simular los puntos por partido que recibirán los Lakers.
# > - Simular el porcentaje de efectividad en los intentos de tiro de 3 puntos de los Lakers.
# > - Simular los rebotes que conseguirán los Lakers.
#
#
# ## Definición del problema
#
# > El problema a trabajar es hacer una predicción sobre la temporada del equipo de baloncesto Los Angeles Lakers, esta predicción será para la temporada 2023-24 y buscará predecir si llegan a los playoffs y si son campeones. Para la resolución del problema se tomará en cuenta las estadísticas de temporada regular y de postemporada de los últimos 4 años, lo que nos da un total de 352 partidos. Aunque la predicción solo será sobre el récord del equipo en temporada regular, los datos de playoffs también nos pueden servir al reflejar el nivel del equipo y su regularidad.
#
#
# ## Nodos y variables que se decidieron simular y porqué
#
# > - Puntos por partido de los Lakers.
# > - Puntos por partido del rival de los Lakers.
# > - Porcentaje de tiros de tres de los Lakers.
# > - Rebotes de los Lakers.
#
# > Elegimos los primeros dos nodos ya que lo más importante al final de todo son los puntos que hacen los equipos. El tercer nodo lo escogemos ya que el tiro de 3 puntos es cada vez más importante en el baloncesto, por lo que nos parece una variable importante. Y el último nodo lo escogemos porque los rebotes son la estadística que más refleja el juego en defensiva de un equipo.
#
# ## Definición de hipótesis y supuestos.
#
# > #### Supuestos:
# > - Los Lakers tendrán a sus 2 super estrellas para la próxima temporada (Lebron James y Anthony Davis).
# > - Se jugarán 82 partidos en temporada regular.
# > - No se ha implementado o modificado ninguna regla dentro de la NBA.
#
# > #### Hipótesis:
# > - El porcentaje de tiro de 3 y los puntos están correlacionados.
# > - Los rebotes y los puntos del rival están correlacionaods.
# > - Los Lakers acabarán con un récord positivo la temporada (más victorias que derrotas).
#
# ## Obtención de bases de datos
#
# > Nuestros datos los obtuvimos de las páginas Basketball Reference y del sitio web de la NBA.

# %%
import pandas as pd
import numpy as np
import scipy.stats as st     
import statsmodels.api as sm 
import matplotlib.pyplot as plt
from scipy import optimize

from scipy import stats
from scipy.stats import pearsonr

from sklearn.neighbors import KernelDensity
from scipy.stats import gaussian_kde
from statsmodels.nonparametric.kde import KDEUnivariate
from statsmodels.nonparametric.kernel_density import KDEMultivariate

from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("Lakers_Stats.csv")
df
# Out:
#                   Date Result  LAL Points  Opp points  LAL 3P%  REB
# 0    Tue, Oct 22, 2019      L         102         112     39.4   41
# 1    Fri, Oct 25, 2019      W          95          86     30.8   42
# 2    Sun, Oct 27, 2019      W         120         101     35.5   47
# 3    Tue, Oct 29, 2019      W         120          91     26.9   54
# 4     Fri, Nov 1, 2019      W         119         110     28.1   41
# ..                 ...    ...         ...         ...      ...  ...
# 347  Fri, May 12, 2023      W         122         101     50.0   46
# 348  Tue, May 16, 2023      L         126         132     45.8   30
# 349  Thu, May 18, 2023      L         103         108     26.7   40
# 350  Sat, May 20, 2023      L         108         119     31.3   45
# 351  Mon, May 22, 2023      L         111         113     40.0   38
#
# [352 rows x 6 columns]

# %%
lal_pts = df["LAL Points"]
three_pts = df["LAL 3P%"]
opp_pts = df["Opp points"]
reb = df["REB"]

# %% [markdown]
# ## Nodo 1: Puntos de los Lakers por partido

# %%
plt.hist(lal_pts)
plt.title("Puntos de los Lakers")
plt.show()

# %% [markdown]
# ### KDE nodo 1

# %%
sns.kdeplot(data = lal_pts, shade = True)
plt.title("Kernel Density Estimation Plot")
plt.xlabel("Lakers Points")
plt.ylabel("Density")
plt.show()

# %% [markdown]
# ### Distribución óptima para el nodo 1

# %%
rv_continuas = [d_i for d_i in dir(st) if isinstance(getattr(st, d_i), getattr(st, 'rv_continuous'))]

fig, ax = plt.subplots(1, 1, figsize = (10,7))

y, x, _ = ax.hist(lal_pts, bins = 50, density = True)
x = x[1:]

error = pd.DataFrame(columns = ['distribucion', 'error'])
i = 0
for d_i in rv_continuas[20:30] + ['beta']:
    try:
        params = getattr(st, d_i).fit(lal_pts)
        data_hat = getattr(st, d_i).pdf(x, *params)
        ax.plot(x, data_hat, label=d_i)
        error.loc[i, :] = [d_i, np.mean((y - data_hat)**2)]
        i += 1
    except ValueError:
        pass

plt.legend()
error.set_index('distribucion', inplace=True)
error.sort_values('error', inplace=True)

# %%
error
# Out:
#                  error
# distribucion
# beta          0.000059
# gamma         0.000059
# f             0.000059
# genextreme    0.000059
# fatiguelife   0.000059
# fisk          0.000065
# foldcauchy    0.000084
# foldnorm      0.000204
# genexpon      0.000259
# gausshyper    0.000281
# exponweib     0.000507

# %% [markdown]
# **La distribución beta es la que menos error tiene. Para saber si se acopla a nuestros datos haremos una comprobación.**

# %% [markdown]
# ### Prueba de hipótesis nodo 1

# %% [markdown]
# **Hipótesis para beta**
#
# $H_{0}$: es una distribución beta.
#
# $H_{a}$: no es una distribución beta.
#
# Nivel de significancia: ${\alpha} = 0.05$
#
# Nivel de confianza: $1-{\alpha} = 0.95$

# %%
params_lalpts = st.beta.fit(lal_pts)
params_lalpts
# Out:
# (6.239369098198521, 6.860205650726678, 70.53068620068866, 88.71703654494223)

# %%
st.kstest(lal_pts, lambda lal_pts: st.beta.cdf(lal_pts, * params_lalpts))
# Out:
# KstestResult(statistic=0.02847278432642808, pvalue=0.9299178389543874, statistic_location=120, statistic_sign=-1)

# %% [markdown]
# **El p-value que tenemos es mayor al nivel de significancia, por lo que podemos aceptar la hipótesis nula, entonces los puntos que anotan los Lakers sí se distribuyen como beta.**

# %% [markdown]
# ### Ajuste PDF nodo 1

# %%
dist = 'beta'
params1 = getattr(st, dist).fit(lal_pts)

random_hat1 = getattr(st, dist).rvs(*params1, size = 100)

plt.hist(lal_pts, bins = 20, label = 'data real', density = True)
plt.hist(random_hat1, bins = 20, density = True, alpha = .5, label = 'data estimado')
plt.legend()
plt.show()

# %% [markdown]
# ### Q-Q nodo 1

# %%
bins = 25
fig, ax = plt.subplots(2, 1, figsize = (8,10))
fig.tight_layout(pad = 3.0)

y, x, _ = ax[0].hist(lal_pts, bins, density=True, label='Histograma mediciones')

params = getattr(st, dist).fit(lal_pts)
y_hat = getattr(st, dist).pdf(x, *params_lalpts)
ax[0].plot(x, y_hat,'r--', label='Distribución ajustada')
ax[0].set_ylabel('Probability')
ax[0].grid()
ax[0].legend()

grap2 = st.probplot(lal_pts, dist=dist, sparams=getattr(st, dist).fit(x)[:-2], plot=ax[1], fit=True)
ax[1].grid()
ax[1].set_title('Usando paquete scipy')

plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# **Podemos ver en la gráfica que la distribución se ajusta de manera correcta.**

# %% [markdown]
# ### Montecarlo nodo 1

# %%
num_simulaciones = 100000

media_lalpts = lal_pts.mean()
desviacion_lalpts = lal_pts.std()

montecarlo_lalpts = np.random.normal(media_lalpts, desviacion_lalpts, num_simulaciones)
montecarlo_lalpts
# Out:
# array([128.75432147, 129.92043548, 125.2127277 , ..., 106.14111108,
#        117.12771836, 114.74267599])

# %% [markdown]
# ### Reducción de varianza nodo 1

# %%
def reducir_varianza(datos):
    return np.log1p(datos)

montecarlo_lalpts_transformado = reducir_varianza(montecarlo_lalpts)

df_varianza1 = pd.DataFrame(columns=['Montecarlo_sin_transformacion', 'Montecarlo_con_transformacion'], dtype='float')
df_varianza1['Montecarlo_sin_transformacion'] = montecarlo_lalpts
df_varianza1['Montecarlo_con_transformacion'] = montecarlo_lalpts_transformado

df_varianza1
# Out:
#        Montecarlo_sin_transformacion  Montecarlo_con_transformacion
# 0                         128.754321                       4.865643
# 1                         129.920435                       4.874590
# 2                         125.212728                       4.837969
# 3                         103.989320                       4.653859
# 4                         120.361591                       4.798774
# ...                              ...                            ...
# 99995                     124.916231                       4.835617
# 99996                     113.356092                       4.739317
# 99997                     106.141111                       4.674147
# 99998                     117.127718                       4.771766
# 99999                     114.742676                       4.751369
#
# [100000 rows x 2 columns]

# %% [markdown]
# ## Nodo 2: Porcentaje de triples de los Lakers

# %%
plt.hist(three_pts)
plt.title("Porcentaje de triples")
plt.show()

# %% [markdown]
# ### KDE nodo 2

# %%
sns.kdeplot(data = three_pts, shade = True)
plt.title("Kernel Density Estimation Plot")
plt.xlabel("3 Points Percentage")
plt.ylabel("Density")
plt.show()

# %% [markdown]
# ### Distribución óptima para el nodo 2

# %%
rv_continuas = [d_i for d_i in dir(st) if isinstance(getattr(st, d_i), getattr(st, 'rv_continuous'))]

fig, ax = plt.subplots(1, 1, figsize = (10,7))

y, x, _ = ax.hist(three_pts, bins = 50, density = True)
x = x[1:]

error = pd.DataFrame(columns = ['distribucion', 'error'])
i = 0
for d_i in rv_continuas[20:30] + ['beta']:
    try:
        params = getattr(st, d_i).fit(three_pts)
        data_hat = getattr(st, d_i).pdf(x, *params)
        ax.plot(x, data_hat, label = d_i)
        error.loc[i, :] = [d_i, np.mean((y - data_hat)**2)]
        i += 1
    except ValueError:
        pass

plt.legend()
error.set_index('distribucion', inplace=True)
error.sort_values('error', inplace=True)

# %%
error
# Out:
#                  error
# distribucion
# genextreme    0.000116
# fatiguelife   0.000117
# exponweib     0.000117
# f             0.000117
# gamma         0.000117
# gausshyper    0.000118
# beta          0.000118
# fisk          0.000121
# foldcauchy    0.000146
# foldnorm      0.000197
# genexpon      0.000548

# %% [markdown]
# **La distribución genextreme es la que menos error tiene. Para saber si se acopla a nuestros datos haremos una comprobación.**

# %% [markdown]
# ### Prueba de hipótesis nodo 2

# %% [markdown]
# **Hipótesis para genextreme**
#
# $H_{0}$: es una distribución genextreme.
#
# $H_{a}$: no es una distribución genextreme.
#
# Nivel de significancia: ${\alpha} = 0.05$
#
# Nivel de confianza: $1-{\alpha} = 0.95$

# %%
params_triples = st.genextreme.fit(three_pts)
params_triples
# Out:
# (0.2824127878364949, 31.900389505091418, 8.148309682571687)

# %%
st.kstest(three_pts, lambda three_pts: st.genextreme.cdf(three_pts, * params_triples))
# Out:
# KstestResult(statistic=0.04777962476050235, pvalue=0.3855973312137225, statistic_location=33.3, statistic_sign=1)

# %% [markdown]
# **El p-value que tenemos es mayor al nivel de significancia, por lo que podemos aceptar la hipótesis nula, entonces el porcentaje de triples que anotan los Lakers sí se distribuye como genextreme.**

# %% [markdown]
# ### Ajuste PDF nodo 2

# %%
dist = 'genextreme'
params2 = getattr(st, dist).fit(three_pts)

random_hat2 = getattr(st, dist).rvs(*params2, size = 100)

plt.hist(three_pts, bins = 20, label = 'data real', density = True)
plt.hist(random_hat2, bins = 20, density = True, alpha = .5, label = 'data estimado')
plt.legend()
plt.show()

# %% [markdown]
# ### Q-Q nodo 2

# %%
bins = 25
fig, ax = plt.subplots(2, 1, figsize = (8,10))
fig.tight_layout(pad = 3.0)

y, x, _ = ax[0].hist(three_pts, bins, density = True, label ='Histograma mediciones') 

params = getattr(st, dist).fit(three_pts)
y_hat = getattr(st, dist).pdf(x, *params)
ax[0].plot(x, y_hat,'r--', label='Distribución ajustada')
ax[0].set_ylabel('Probability')
ax[0].grid()
ax[0].legend()

grap2 = st.probplot(three_pts, dist=dist, sparams=getattr(st, dist).fit(x)[:-2], plot=ax[1], fit=True)
ax[1].grid()
ax[1].set_title('Usando paquete scipy')

plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# **Podemos ver en la gráfica que la distribución se ajusta de manera correcta.**

# %% [markdown]
# ### Montecarlo nodo 2

# %%
num_simulaciones = 100000

media_triples = three_pts.mean()
desviacion_triples = three_pts.std()

montecarlo_triples = np.random.normal(media_triples, desviacion_triples, num_simulaciones)
montecarlo_triples
# Out:
# array([26.54448915, 28.41189652, 27.11757496, ..., 47.50745201,
#        26.99879105, 45.30638009])

# %% [markdown]
# ### Reducción de varianza  nodo 2

# %%
montecarlo_triples_transformado = reducir_varianza(montecarlo_triples)

df_varianza2 = pd.DataFrame(columns=['Montecarlo_sin_transformacion', 'Montecarlo_con_transformacion'], dtype='float')
df_varianza2['Montecarlo_sin_transformacion'] = montecarlo_triples
df_varianza2['Montecarlo_con_transformacion'] = montecarlo_triples_transformado

df_varianza2
# Out:
#        Montecarlo_sin_transformacion  Montecarlo_con_transformacion
# 0                          31.964505                       3.495431
# 1                          38.913213                       3.686707
# 2                          50.962629                       3.950525
# 3                          39.590119                       3.703525
# 4                          35.999219                       3.610897
# ...                              ...                            ...
# 99995                      30.542930                       3.451349
# 99996                      36.383901                       3.621240
# 99997                      37.621524                       3.653810
# 99998                      19.163258                       3.003862
# 99999                      34.234570                       3.562028
#
# [100000 rows x 2 columns]

# %% [markdown]
# ## Nodo 3: Rebotes de los Lakers

# %%
plt.hist(reb)
plt.title("Rebotes")
plt.show()

# %% [markdown]
# ### KDE nodo 3

# %%
sns.kdeplot(data = reb, shade = True)
plt.title("Kernel Density Estimation Plot")
plt.xlabel("Rebounds")
plt.ylabel("Density")
plt.show()

# %% [markdown]
# ### Distribución óptima para el nodo 3

# %%
rv_continuas = [d_i for d_i in dir(st) if isinstance(getattr(st, d_i), getattr(st, 'rv_continuous'))]

fig, ax = plt.subplots(1, 1, figsize = (10,7))

y, x, _ = ax.hist(reb, bins = 50, density = True)
x = x[1:]

error = pd.DataFrame(columns = ['distribucion', 'error'])
i = 0
for d_i in rv_continuas[20:30] + ['beta']:
    try:
        params = getattr(st, d_i).fit(reb)
        data_hat = getattr(st, d_i).pdf(x, *params)
        ax.plot(x, data_hat, label = d_i)
        error.loc[i, :] = [d_i, np.mean((y - data_hat)**2)]
        i += 1
    except ValueError:
        pass

plt.legend()
error.set_index('distribucion', inplace=True)
error.sort_values('error', inplace=True)

# %%
error
# Out:
#                  error
# distribucion
# fatiguelife   0.000543
# f             0.000543
# gamma         0.000543
# beta          0.000543
# genextreme    0.000543
# foldnorm      0.000543
# fisk           0.00055
# foldcauchy    0.000634
# gausshyper    0.000689
# genexpon      0.001357
# exponweib     0.002219

# %% [markdown]
# **La distribución fatiguelife es la que menos error tiene. Para saber si se acopla a nuestros datos haremos una comprobación.**

# %% [markdown]
# ### Prueba de hipótesis nodo 3

# %% [markdown]
# **Hipótesis para fatiguelife**
#
# $H_{0}$: es una distribución fatiguelife.
#
# $H_{a}$: no es una distribución fatiguelife.
#
# Nivel de significancia: ${\alpha} = 0.05$
#
# Nivel de confianza: $1-{\alpha} = 0.95$

# %%
params_rebotes = st.fatiguelife.fit(reb)
params_rebotes
# Out:
# (0.022967594139472206, -223.41982267271817, 268.1625206622052)

# %%
st.kstest(reb, lambda reb: st.fatiguelife.cdf(reb, * params_rebotes))
# Out:
# KstestResult(statistic=0.05436923890079681, pvalue=0.24028558558128044, statistic_location=45, statistic_sign=1)

# %% [markdown]
# **El p-value que tenemos es mayor al nivel de significancia, por lo que podemos aceptar la hipótesis nula, entonces los rebotes que realizan los Lakers sí se distribuyen como genextreme.**

# %% [markdown]
# ### Ajuste PDF nodo 3

# %%
dist = 'fatiguelife'
params3 = getattr(st, dist).fit(reb)

random_hat3 = getattr(st, dist).rvs(*params3, size = 100)

plt.hist(reb, bins = 20, label = 'data real', density = True)
plt.hist(random_hat3, bins = 20, density = True, alpha = .5, label = 'data estimado')
plt.legend()
plt.show()

# %% [markdown]
# ### Q-Q nodo 3

# %%
bins = 25
fig, ax = plt.subplots(2, 1, figsize = (8,10))
fig.tight_layout(pad = 3.0)

y, x, _ = ax[0].hist(reb, bins, density = True, label ='Histograma mediciones') 

params = getattr(st, dist).fit(reb)
y_hat = getattr(st, dist).pdf(x, *params)
ax[0].plot(x, y_hat,'r--', label='Distribución ajustada')
ax[0].set_ylabel('Probability')
ax[0].grid()
ax[0].legend()

grap2 = st.probplot(reb, dist=dist, sparams=getattr(st, dist).fit(x)[:-2], plot=ax[1], fit=True)
ax[1].grid()
ax[1].set_title('Usando paquete scipy')

plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# **Podemos ver en la gráfica que la distribución se ajusta de manera correcta.**

# %% [markdown]
# ### Montecarlo nodo 3

# %%
num_simulaciones = 100000

media_rebotes = reb.mean()
desviacion_rebotes = reb.std()

montecarlo_rebotes = np.random.normal(media_rebotes, desviacion_rebotes, num_simulaciones)
montecarlo_rebotes
# Out:
# array([43.17752812, 56.95352676, 43.89944467, ..., 43.91571157,
#        40.41132563, 41.5143703 ])

# %% [markdown]
# ### Reducción de varianza nodo 3

# %%
montecarlo_rebotes_transformado = reducir_varianza(montecarlo_rebotes)

df_varianza3 = pd.DataFrame(columns=['Montecarlo_sin_transformacion', 'Montecarlo_con_transformacion'], dtype='float')
df_varianza3['Montecarlo_sin_transformacion'] = montecarlo_rebotes
df_varianza3['Montecarlo_con_transformacion'] = montecarlo_rebotes_transformado

df_varianza3
# Out:
#        Montecarlo_sin_transformacion  Montecarlo_con_transformacion
# 0                          43.177528                       3.788216
# 1                          56.953527                       4.059641
# 2                          43.899445                       3.804425
# 3                          46.333537                       3.857219
# 4                          41.543710                       3.750532
# ...                              ...                            ...
# 99995                      48.423125                       3.900418
# 99996                      49.704739                       3.926019
# 99997                      43.915712                       3.804788
# 99998                      40.411326                       3.723554
# 99999                      41.514370                       3.749842
#
# [100000 rows x 2 columns]

# %% [markdown]
# ## Nodo 4: Puntos de los rivales

# %%
plt.hist(opp_pts)
plt.title("Puntos de los rivales")
plt.show()

# %% [markdown]
# ### KDE nodo 4

# %%
sns.kdeplot(data = opp_pts, shade = True)
plt.title("Kernel Density Estimation Plot")
plt.xlabel("Rebounds")
plt.ylabel("Density")
plt.show()

# %% [markdown]
# ### Distribución óptima para el nodo 4

# %%
rv_continuas = [d_i for d_i in dir(st) if isinstance(getattr(st, d_i), getattr(st, 'rv_continuous'))]

fig, ax = plt.subplots(1, 1, figsize = (10,7))

y, x, _ = ax.hist(opp_pts, bins = 50, density = True)
x = x[1:]

error = pd.DataFrame(columns = ['distribucion', 'error'])
i = 0
for d_i in rv_continuas[20:30] + ['beta']:
    try:
        params = getattr(st, d_i).fit(opp_pts)
        data_hat = getattr(st, d_i).pdf(x, *params)
        ax.plot(x, data_hat, label = d_i)
        error.loc[i, :] = [d_i, np.mean((y - data_hat)**2)]
        i += 1
    except ValueError:
        pass

plt.legend()
error.set_index('distribucion', inplace=True)
error.sort_values('error', inplace=True)

# %%
error
# Out:
#                  error
# distribucion
# fisk          0.000074
# f             0.000074
# gamma         0.000074
# fatiguelife   0.000074
# genextreme    0.000075
# beta          0.000075
# foldcauchy    0.000091
# foldnorm      0.000245
# genexpon        0.0003
# exponweib     0.000603
# gausshyper    0.010747

# %% [markdown]
# **La distribución fisk es la que menos error tiene. Para saber si se acopla a nuestros datos haremos una comprobación.**

# %% [markdown]
# ### Prueba de hipótesis nodo 4

# %% [markdown]
# **Hipótesis para beta**
#
# $H_{0}$: es una distribución beta.
#
# $H_{a}$: no es una distribución beta.
#
# Nivel de significancia: ${\alpha} = 0.05$
#
# Nivel de confianza: $1-{\alpha} = 0.95$

# %%
params_pts_rival = st.fisk.fit(opp_pts)
params_pts_rival
# Out:
# (16.66050360818337, -0.7706369750411448, 111.54911812311826)

# %%
st.kstest(opp_pts, lambda opp_pts: st.fisk.cdf(opp_pts, * params_pts_rival))
# Out:
# KstestResult(statistic=0.036671416136754675, pvalue=0.716783457477115, statistic_location=111, statistic_sign=-1)

# %% [markdown]
# **El p-value que tenemos es mayor al nivel de significancia, por lo que podemos aceptar la hipótesis nula, entonces los rebotes que realizan los Lakers sí se distribuyen como fisk.**

# %% [markdown]
# ### Ajuste PDF nodo 4

# %%
dist = 'fisk'
params = getattr(st, dist).fit(opp_pts)

random_hat = getattr(st, dist).rvs(*params, size = 100)

plt.hist(opp_pts, bins = 20, label = 'data real', density = True)
plt.hist(random_hat, bins = 20, density = True, alpha = .5, label = 'data estimado')
plt.legend()
plt.show()

# %% [markdown]
# ### Q-Q nodo 4

# %%
bins = 25
fig, ax = plt.subplots(2, 1, figsize = (8,10))
fig.tight_layout(pad = 3.0)

y, x, _ = ax[0].hist(reb, bins, density = True, label ='Histograma mediciones') 

params = getattr(st, dist).fit(reb)
y_hat = getattr(st, dist).pdf(x, *params)
ax[0].plot(x, y_hat,'r--', label='Distribución ajustada')
ax[0].set_ylabel('Probability')
ax[0].grid()
ax[0].legend()

grap2 = st.probplot(opp_pts, dist=dist, sparams=getattr(st, dist).fit(x)[:-2], plot=ax[1], fit=True)
ax[1].grid()
ax[1].set_title('Usando paquete scipy')

plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# **Podemos ver en la gráfica que la distribución se ajusta de manera correcta.**

# %% [markdown]
# ### Montecarlo nodo 4

# %%
num_simulaciones = 100000

media_pts_rivales = opp_pts.mean()
desviacion_pts_rivales = opp_pts.std()

montecarlo_pts_rivales = np.random.normal(media_pts_rivales, desviacion_pts_rivales, num_simulaciones)
montecarlo_pts_rivales
# Out:
# array([108.32581047,  76.04526954, 116.25569581, ..., 110.83404771,
#        105.63316586, 133.10139352])

# %% [markdown]
# ### Reducción de varianza nodo 4

# %%
montecarlo_pts_rivales_transformado = reducir_varianza(montecarlo_pts_rivales)

df_varianza4 = pd.DataFrame(columns=['Montecarlo_sin_transformacion', 'Montecarlo_con_transformacion'], dtype='float')
df_varianza4['Montecarlo_sin_transformacion'] = montecarlo_pts_rivales
df_varianza4['Montecarlo_con_transformacion'] = montecarlo_pts_rivales_transformado

df_varianza4
# Out:
#        Montecarlo_sin_transformacion  Montecarlo_con_transformacion
# 0                         108.325810                       4.694333
# 1                          76.045270                       4.344393
# 2                         116.255696                       4.764357
# 3                         123.045517                       4.820649
# 4                          90.220285                       4.513277
# ...                              ...                            ...
# 99995                     112.896590                       4.735291
# 99996                     117.765615                       4.777152
# 99997                     110.834048                       4.717016
# 99998                     105.633166                       4.669395
# 99999                     133.101394                       4.898596
#
# [100000 rows x 2 columns]

# %% [markdown]
# ## Predicción de los resultados de esta temporada

# %% [markdown]
# Para sacar conclusiones sobre nuestra predicción, primero comparamos los números de los años que tenemos junto con los resultados que alcanzaron

# %% [markdown]
# #### Año 1
# * Playoffs: Si
# * Campeón: Si
# * Promedio pts: 113.29
# * Promedio 3%: 34.87
# * Promedio rebotes: 45.39
# * Promedio puntos rivales: 107.26
#
# #### Año 2
# * Playoffs: Si
# * Campeón: No
# * Promedio pts: 108.54
# * Promedio 3%: 34.86
# * Promedio rebotes: 44.11
# * Promedio puntos rivales: 106.45
#
# #### Año 3
# * Playoffs: No
# * Campeón: No
# * Promedio pts: 111.67
# * Promedio 3%: 34.65
# * Promedio rebotes: 43.86
# * Promedio puntos rivales: 114.82
#
# #### Año 4
# * Playoffs: Si
# * Campeón: No
# * Promedio pts: 116.59
# * Promedio 3%: 34.71
# * Promedio rebotes: 45.6
# * Promedio puntos rivales: 115.63

# %%
montecarlo_lalpts.mean()
# Out:
# 112.79540986899345

# %%
montecarlo_triples.mean()
# Out:
# 34.80710553687089

# %%
montecarlo_rebotes.mean()
# Out:
# 44.78907969904089

# %%
montecarlo_pts_rivales.mean()
# Out:
# 111.1966814383545

# %% [markdown]
# #### Primera premisa (playoffs):
# * Cuando los Lakers promediaron más puntos que sus rivales, llegaron a playoffs.
#
# **En nuestras simulaciones se cumple esta premisa.**

# %% [markdown]
# #### Segunda premisa (playoffs):
# * Cuando los Lakers promediaron arriba de 44 rebotes, llegaron a playoffs.
#
# **En nuestras simulaciones se cumple esta premisa.**

# %% [markdown]
# #### Tercera premisa (playoffs):
# * Cuando los Lakers promediaron abajo de 110 puntos, no llegaron a playoffs.
#
# **En nuestras simulaciones no se cumple esta premisa.**

# %% [markdown]
# > Según nuestras simulaciones
# > ## Los Lakers alcanzarán los playoffs.
#
# <img style="display: block; margin: auto;" src="https://pbs.twimg.com/media/FtfSiixWIAcF3-X.jpg" width="300px" height="100px" />

# %% [markdown]
# #### Primera premisa (campeonato):
# * Cuando los Lakers promediaron arriba de 112 puntos y alcanzaron un porcentaje de triples mayor a 34.75%, fueron campeones de la NBA.
#
# **En nuestras simulaciones se cumple esta premisa.**

# %% [markdown]
# #### Segunda premisa (campeonato):
# * Cuando los Lakers promediaron abajo de 44.5 rebotes y alcanzaron un porcentaje de triples menor a 34.8%, no fueron campeones de la NBA.
#
# **En nuestras simulaciones no se cumple esta premisa.**

# %% [markdown]
# #### Tercera premisa (campeonato):
# * Cuando los Lakers promediaron arriba de 112 puntos anotados y abajo de la misma cantidad recibidos, fueron campeones de la NBA.
#
# **En nuestras simulaciones se cumple esta premisa.**

# %% [markdown]
# > Según nuestras simulaciones:
# > ## Los Lakers serán campeones de la NBA.
#
# <img style="display: block; margin: auto;" src="https://lmdiario.com.ar/download/multimedia.normal.93702d1005ad1fbb.4c616b657273204e42412063616d70656f6e65735f6e6f726d616c2e6a7067.jpg" width="400px" height="150px" />

# %% [markdown]
# ------------
#
# ## Referencias
#
# > * 2022-23 Los Angeles Lakers Schedule | Basketball-Reference.com. (n.d.). Basketball-Reference.com. https://www.basketball-reference.com/teams/LAL/2023_games.html
# > * 2021-22 Los Angeles Lakers Schedule | Basketball-Reference.com. (n.d.). Basketball-Reference.com. https://www.basketball-reference.com/teams/LAL/2022_games.html
# > * 2020-21 Los Angeles Lakers Schedule | Basketball-Reference.com. (n.d.). Basketball-Reference.com. https://www.basketball-reference.com/teams/LAL/2021_games.html
# > * 2019-20 Los Angeles Lakers Schedule | Basketball-Reference.com. (n.d.). Basketball-Reference.com. https://www.basketball-reference.com/teams/LAL/2020_games.html
# > * Los Angeles Lakers team info and news | NBA.com. (n.d.). https://www.nba.com/stats/team/1610612747/boxscores-traditional

# %% [markdown]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#808080; background:#fff;">
# Created with Jupyter by Esteban Jiménez Rodríguez.
# </footer>
